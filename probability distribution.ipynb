# %% [markdown]
# <a href="https://colab.research.google.com/github/mehektamboli/python/blob/main/probability%20distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

n=11

p=0.5

q=1-p

print("Probability of getting k heads in 10 tosses:/n")

for k in range(n + 1):
    probability = math.comb(n, k) * (p ** k) * (q ** (n - k))
    print(f"P(X = {k}) = {probability:.5f}")


expected_heads = n * p
expected_tails = n * q

print("\nExpected Number of Heads:", expected_heads)
print("Expected Number of Tails:", expected_tails)
# Out:
# Probability of getting k heads in 10 tosses:/n
# P(X = 0) = 0.00049
# P(X = 1) = 0.00537
# P(X = 2) = 0.02686
# P(X = 3) = 0.08057
# P(X = 4) = 0.16113
# P(X = 5) = 0.22559
# P(X = 6) = 0.22559
# P(X = 7) = 0.16113
# P(X = 8) = 0.08057
# P(X = 9) = 0.02686
# P(X = 10) = 0.00537
# P(X = 11) = 0.00049
#
# Expected Number of Heads: 5.5
# Expected Number of Tails: 5.5
